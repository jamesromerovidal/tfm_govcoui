# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 915.3/915.3 kB 15.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 102.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 76.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 50.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 38.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 18.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.3 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
#/content/drive/MyDrive/ColabNotebooks/TFM/dataset_v10
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from ultralytics import YOLO
import shutil

# Build a new model from YAML and start training from scratch
#model = YOLO('yolo11m.yaml')
#results = model.train(data='/content/drive/MyDrive/ColabNotebooks/TFM/dataset_v24/data.yaml', epochs=200,
 #                     batch=16, task="detect", device=0, workers=8, patience=20, dropout=0.0, img)

model = YOLO('yolo11l.pt')
model_name = 'model.yolo11l.pt'
results = model.train(data='/content/drive/MyDrive/ColabNotebooks/TFM/v30i.yolov11/data.yaml', name=model_name,
                      epochs=250, batch=16, task="detect", device=0, workers=8, patience=20, dropout=0.0)

# Evaluate the model's performance on the validation set
results = model.val()

# Export the model to ONNX
success = model.export(model="best.pt", format='onnx')

shutil.move('/content/runs/detect/' + model_name, '/content/drive/MyDrive/ColabNotebooks/TFM/')
# Out:
# Ultralytics 8.3.77 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
shutil.move('/content/runs/detect/model.yolo11l.pt2', '/content/drive/MyDrive/ColabNotebooks/TFM/')
# Out:
# '/content/drive/MyDrive/ColabNotebooks/TFM/model.yolo11l.pt2'
